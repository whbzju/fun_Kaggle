# %% [markdown]
# # kaggle titanic教程---随机森林应用

# %%
# %matplotlib inline
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('train.csv')
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex  Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male   22      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female   38      1
# 2                             Heikkinen, Miss. Laina  female   26      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female   35      1
# 4                           Allen, Mr. William Henry    male   35      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
df.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
df["Age"].unique()
# Out:
# array([ 22.  ,  38.  ,  26.  ,  35.  ,    nan,  54.  ,   2.  ,  27.  ,
#         14.  ,   4.  ,  58.  ,  20.  ,  39.  ,  55.  ,  31.  ,  34.  ,
#         15.  ,  28.  ,   8.  ,  19.  ,  40.  ,  66.  ,  42.  ,  21.  ,
#         18.  ,   3.  ,   7.  ,  49.  ,  29.  ,  65.  ,  28.5 ,   5.  ,
#         11.  ,  45.  ,  17.  ,  32.  ,  16.  ,  25.  ,   0.83,  30.  ,
#         33.  ,  23.  ,  24.  ,  46.  ,  59.  ,  71.  ,  37.  ,  47.  ,
#         14.5 ,  70.5 ,  32.5 ,  12.  ,   9.  ,  36.5 ,  51.  ,  55.5 ,
#         40.5 ,  44.  ,   1.  ,  61.  ,  56.  ,  50.  ,  36.  ,  45.5 ,
#         20.5 ,  62.  ,  41.  ,  52.  ,  63.  ,  23.5 ,   0.92,  43.  ,
#         60.  ,  10.  ,  64.  ,  13.  ,  48.  ,   0.75,  53.  ,  57.  ,
#         80.  ,  70.  ,  24.5 ,   6.  ,   0.67,  30.5 ,   0.42,  34.5 ,  74.  ])

# %%
df[df['Age'] > 60][['Sex', 'Pclass', 'Age', 'Survived']]
# Out:
#         Sex  Pclass   Age  Survived
# 33     male       2  66.0         0
# 54     male       1  65.0         0
# 96     male       1  71.0         0
# 116    male       3  70.5         0
# 170    male       1  61.0         0
# 252    male       1  62.0         0
# 275  female       1  63.0         1
# 280    male       3  65.0         0
# 326    male       3  61.0         0
# 438    male       1  64.0         0
# 456    male       1  65.0         0
# 483  female       3  63.0         1
# 493    male       1  71.0         0
# 545    male       1  64.0         0
# 555    male       1  62.0         0
# 570    male       2  62.0         1
# 625    male       1  61.0         0
# 630    male       1  80.0         1
# 672    male       2  70.0         0
# 745    male       1  70.0         0
# 829  female       1  62.0         1
# 851    male       3  74.0         0

# %%
df[df['Age'].isnull()][['Sex', 'Pclass', 'Age']]
# Out:
#         Sex  Pclass  Age
# 5      male       3  NaN
# 17     male       2  NaN
# 19   female       3  NaN
# 26     male       3  NaN
# 28   female       3  NaN
# 29     male       3  NaN
# 31   female       1  NaN
# 32   female       3  NaN
# 36     male       3  NaN
# 42     male       3  NaN
# 45     male       3  NaN
# 46     male       3  NaN
# 47   female       3  NaN
# 48     male       3  NaN
# 55     male       1  NaN
# 64     male       1  NaN
# 65     male       3  NaN
# 76     male       3  NaN
# 77     male       3  NaN
# 82   female       3  NaN
# 87     male       3  NaN
# 95     male       3  NaN
# 101    male       3  NaN
# 107    male       3  NaN
# 109  female       3  NaN
# 121    male       3  NaN
# 126    male       3  NaN
# 128  female       3  NaN
# 140  female       3  NaN
# 154    male       3  NaN
# ..      ...     ...  ...
# 718    male       3  NaN
# 727  female       3  NaN
# 732    male       2  NaN
# 738    male       3  NaN
# 739    male       3  NaN
# ...

# %%
fig, axs = plt.subplots(1,2)

df['Age'].hist(ax=axs[0])
df['SibSp'].hist(ax=axs[1])

# %%
for i in range(1,4):
    print i, len(df[ (df['Sex'] == 'male') & (df['Pclass'] == i) ])
# Out:
# 1 122
# 2 108
# 3 347

# %%
df['Gender'] = df['Sex'].map( {'female': 0, 'male': 1} ).astype(int)
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex  Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male   22      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female   38      1
# 2                             Heikkinen, Miss. Laina  female   26      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female   35      1
# 4                           Allen, Mr. William Henry    male   35      0
#
#    Parch            Ticket     Fare Cabin Embarked  Gender
# 0      0         A/5 21171   7.2500   NaN        S       1
# 1      0          PC 17599  71.2833   C85        C       0
# 2      0  STON/O2. 3101282   7.9250   NaN        S       0
# 3      0            113803  53.1000  C123        S       0
# ...

# %%
df["Embarked_d"] = df["Embarked"].map({"C":0, "Q":1, "S":2})
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex  Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male   22      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female   38      1
# 2                             Heikkinen, Miss. Laina  female   26      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female   35      1
# 4                           Allen, Mr. William Henry    male   35      0
#
#    Parch            Ticket     Fare Cabin Embarked  Gender  Embarked_d
# 0      0         A/5 21171   7.2500   NaN        S       1           2
# 1      0          PC 17599  71.2833   C85        C       0           0
# 2      0  STON/O2. 3101282   7.9250   NaN        S       0           2
# ...

# %%
df['Age'].unique()
# Out:
# array([ 22.  ,  38.  ,  26.  ,  35.  ,    nan,  54.  ,   2.  ,  27.  ,
#         14.  ,   4.  ,  58.  ,  20.  ,  39.  ,  55.  ,  31.  ,  34.  ,
#         15.  ,  28.  ,   8.  ,  19.  ,  40.  ,  66.  ,  42.  ,  21.  ,
#         18.  ,   3.  ,   7.  ,  49.  ,  29.  ,  65.  ,  28.5 ,   5.  ,
#         11.  ,  45.  ,  17.  ,  32.  ,  16.  ,  25.  ,   0.83,  30.  ,
#         33.  ,  23.  ,  24.  ,  46.  ,  59.  ,  71.  ,  37.  ,  47.  ,
#         14.5 ,  70.5 ,  32.5 ,  12.  ,   9.  ,  36.5 ,  51.  ,  55.5 ,
#         40.5 ,  44.  ,   1.  ,  61.  ,  56.  ,  50.  ,  36.  ,  45.5 ,
#         20.5 ,  62.  ,  41.  ,  52.  ,  63.  ,  23.5 ,   0.92,  43.  ,
#         60.  ,  10.  ,  64.  ,  13.  ,  48.  ,   0.75,  53.  ,  57.  ,
#         80.  ,  70.  ,  24.5 ,   6.  ,   0.67,  30.5 ,   0.42,  34.5 ,  74.  ])

# %%
#df.loc[pd.isnull(df['Age']).loc[:, 'Age'] = df['Age'].mean()
#df['Age'] = df['Age'].fillna(df['Age'].mean())

# %%
median_ages = np.zeros((2,3))
median_ages
# Out:
# array([[ 0.,  0.,  0.],
#        [ 0.,  0.,  0.]])

# %%
for i in range(0, 2):
    for j in range(0, 3):
        median_ages[i,j] = df[(df['Gender'] == i) & \
                              (df['Pclass'] == j+1)]['Age'].dropna().median()
 
median_ages
# Out:
# array([[ 35. ,  28. ,  21.5],
#        [ 40. ,  30. ,  25. ]])

# %%
df['AgeFill'] = df['Age']

df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex  Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male   22      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female   38      1
# 2                             Heikkinen, Miss. Laina  female   26      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female   35      1
# 4                           Allen, Mr. William Henry    male   35      0
#
#    Parch            Ticket     Fare Cabin Embarked  Gender  Embarked_d  \
# 0      0         A/5 21171   7.2500   NaN        S       1           2
# 1      0          PC 17599  71.2833   C85        C       0           0
# 2      0  STON/O2. 3101282   7.9250   NaN        S       0           2
# ...

# %%
df[ df['Age'].isnull() ][['Gender','Pclass','Age','AgeFill']].head(10)
# Out:
#     Gender  Pclass  Age  AgeFill
# 5        1       3  NaN      NaN
# 17       1       2  NaN      NaN
# 19       0       3  NaN      NaN
# 26       1       3  NaN      NaN
# 28       0       3  NaN      NaN
# 29       1       3  NaN      NaN
# 31       0       1  NaN      NaN
# 32       0       3  NaN      NaN
# 36       1       3  NaN      NaN
# 42       1       3  NaN      NaN

# %%
for i in range(0, 2):
    for j in range(0, 3):
        df.loc[ (df.Age.isnull()) & (df.Gender == i) & (df.Pclass == j+1),\
                'AgeFill'] = median_ages[i,j]

# %%
df[ df['Age'].isnull() ][['Gender','Pclass','Age','AgeFill']].head(10)
# Out:
#     Gender  Pclass  Age  AgeFill
# 5        1       3  NaN     25.0
# 17       1       2  NaN     30.0
# 19       0       3  NaN     21.5
# 26       1       3  NaN     25.0
# 28       0       3  NaN     21.5
# 29       1       3  NaN     25.0
# 31       0       1  NaN     35.0
# 32       0       3  NaN     21.5
# 36       1       3  NaN     25.0
# 42       1       3  NaN     25.0

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex  Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male   22      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female   38      1
# 2                             Heikkinen, Miss. Laina  female   26      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female   35      1
# 4                           Allen, Mr. William Henry    male   35      0
#
#    Parch            Ticket     Fare Cabin Embarked  Gender  Embarked_d  \
# 0      0         A/5 21171   7.2500   NaN        S       1           2
# 1      0          PC 17599  71.2833   C85        C       0           0
# 2      0  STON/O2. 3101282   7.9250   NaN        S       0           2
# ...

# %%
df['AgeIsNull'] = pd.isnull(df.Age).astype(int)

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex  Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male   22      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female   38      1
# 2                             Heikkinen, Miss. Laina  female   26      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female   35      1
# 4                           Allen, Mr. William Henry    male   35      0
#
#    Parch            Ticket     Fare Cabin Embarked  Gender  Embarked_d  \
# 0      0         A/5 21171   7.2500   NaN        S       1           2
# 1      0          PC 17599  71.2833   C85        C       0           0
# 2      0  STON/O2. 3101282   7.9250   NaN        S       0           2
# ...

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare      Gender  Embarked_d     AgeFill   AgeIsNull
# count  891.000000  891.000000  891.000000  889.000000  891.000000  891.000000
# mean     0.381594   32.204208    0.647587    1.535433   29.112424    0.198653
# std      0.806057   49.693429    0.477990    0.792088   13.304424    0.399210
# ...

# %%
df['FamilySize'] = df['SibSp'] + df['Parch']

# %%
df['Age*Class'] = df.AgeFill * df.Pclass

# %%
df['Age*Class'].hist()

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex  Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male   22      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female   38      1
# 2                             Heikkinen, Miss. Laina  female   26      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female   35      1
# 4                           Allen, Mr. William Henry    male   35      0
#
#    Parch            Ticket     Fare Cabin Embarked  Gender  Embarked_d  \
# 0      0         A/5 21171   7.2500   NaN        S       1           2
# 1      0          PC 17599  71.2833   C85        C       0           0
# 2      0  STON/O2. 3101282   7.9250   NaN        S       0           2
# ...

# %%
df.dtypes[df.dtypes.map(lambda x: x=='object')]
# Out:
# Name        object
# Sex         object
# Ticket      object
# Cabin       object
# Embarked    object
# dtype: object

# %%
df = df.drop(['Name', 'Sex', 'Ticket', 'Cabin', 'Embarked'], axis=1)

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  Age  SibSp  Parch     Fare  Gender  \
# 0            1         0       3   22      1      0   7.2500       1
# 1            2         1       1   38      1      0  71.2833       0
# 2            3         1       3   26      0      0   7.9250       0
# 3            4         1       1   35      1      0  53.1000       0
# 4            5         0       3   35      0      0   8.0500       1
#
#    Embarked_d  AgeFill  AgeIsNull  FamilySize  Age*Class
# 0           2       22          0           1         66
# 1           0       38          0           1         38
# 2           2       26          0           0         78
# 3           2       35          0           1         35
# 4           2       35          0           0        105

# %%
df = df.drop(['Age'], axis=1)
df.head()
# Out:
#    PassengerId  Survived  Pclass  SibSp  Parch     Fare  Gender  Embarked_d  \
# 0            1         0       3      1      0   7.2500       1           2
# 1            2         1       1      1      0  71.2833       0           0
# 2            3         1       3      0      0   7.9250       0           2
# 3            4         1       1      1      0  53.1000       0           2
# 4            5         0       3      0      0   8.0500       1           2
#
#    AgeFill  AgeIsNull  FamilySize  Age*Class
# 0       22          0           1         66
# 1       38          0           1         38
# 2       26          0           0         78
# 3       35          0           1         35
# 4       35          0           0        105

# %%
groups = df.groupby('Embarked_d').sum()

# %%
groups
# Out:
#             PassengerId  Survived  Pclass  SibSp  Parch        Fare  Gender  \
# Embarked_d
# 0                 74820        93     317     65     61  10072.2962      95
# 1                 32178        30     224     33     13   1022.2543      41
# 2                289496       217    1514    368    266  17439.3988     441
#
#              AgeFill  AgeIsNull  FamilySize  Age*Class
# Embarked_d
# 0            5081.42         38         126    8384.76
# 1            1934.00         49          46    5533.00
# 2           18823.75         90         634   41772.08

# %%
df[ df['Embarked_d'].isnull() ][['Survived','Embarked_d','Gender','Pclass','AgeFill']].head(10)
# Out:
#      Survived  Embarked_d  Gender  Pclass  AgeFill
# 61          1         NaN       0       1       38
# 829         1         NaN       0       1       62

# %%
df.loc[df.Embarked_d.isnull(), 'Embarked_d'] = 2

# %%
df[ df['Embarked_d'].isnull() ][['Survived','Embarked_d','Gender','Pclass','AgeFill']].head(10)
# Out:
# Empty DataFrame
# Columns: [Survived, Embarked_d, Gender, Pclass, AgeFill]
# Index: []

# %%
train_data = df.drop(['Survived'], axis=1).values
label_data = df['Survived'].values
from sklearn.ensemble import RandomForestClassifier
clf = RandomForestClassifier(n_estimators=100)
clf.fit(train_data, label_data)
# Out:
# RandomForestClassifier(bootstrap=True, compute_importances=None,
#             criterion='gini', max_depth=None, max_features='auto',
#             max_leaf_nodes=None, min_density=None, min_samples_leaf=1,
#             min_samples_split=2, n_estimators=100, n_jobs=1,
#             oob_score=False, random_state=None, verbose=0)

# %%
from sklearn.cross_validation import cross_val_score
scores = cross_val_score(clf, train_data, label_data) 
print scores
# Out:
# [ 0.81144781  0.80808081  0.84848485]

# %%
df["SibSp"].hist()

# %%
df["Parch"].unique()
# Out:
# array([0, 1, 2, 5, 3, 4, 6])

# %%
df['Parch'].hist()

# %%
df["Fare"].unique()
# Out:
# array([   7.25  ,   71.2833,    7.925 ,   53.1   ,    8.05  ,    8.4583,
#          51.8625,   21.075 ,   11.1333,   30.0708,   16.7   ,   26.55  ,
#          31.275 ,    7.8542,   16.    ,   29.125 ,   13.    ,   18.    ,
#           7.225 ,   26.    ,    8.0292,   35.5   ,   31.3875,  263.    ,
#           7.8792,    7.8958,   27.7208,  146.5208,    7.75  ,   10.5   ,
#          82.1708,   52.    ,    7.2292,   11.2417,    9.475 ,   21.    ,
#          41.5792,   15.5   ,   21.6792,   17.8   ,   39.6875,    7.8   ,
#          76.7292,   61.9792,   27.75  ,   46.9   ,   80.    ,   83.475 ,
#          27.9   ,   15.2458,    8.1583,    8.6625,   73.5   ,   14.4542,
#          56.4958,    7.65  ,   29.    ,   12.475 ,    9.    ,    9.5   ,
#           7.7875,   47.1   ,   15.85  ,   34.375 ,   61.175 ,   20.575 ,
#          34.6542,   63.3583,   23.    ,   77.2875,    8.6542,    7.775 ,
#          24.15  ,    9.825 ,   14.4583,  247.5208,    7.1417,   22.3583,
# ...

# %%
df['Fare'].hist()

# %%
df[df['Fare']>300].head()
# Out:
#      PassengerId  Survived  Pclass                                Name  \
# 258          259         1       1                    Ward, Miss. Anna
# 679          680         1       1  Cardeza, Mr. Thomas Drake Martinez
# 737          738         1       1              Lesurer, Mr. Gustave J
#
#         Sex  Age  SibSp  Parch    Ticket      Fare        Cabin Embarked
# 258  female   35      0      0  PC 17755  512.3292          NaN        C
# 679    male   36      0      1  PC 17755  512.3292  B51 B53 B55        C
# 737    male   35      0      0  PC 17755  512.3292         B101        C

# %%
df['Embarked'].unique()
# Out:
# array(['S', 'C', 'Q', nan], dtype=object)

# %%
df['Sex'].unique()
# Out:
# array(['male', 'female'], dtype=object)

# %%
df["Gender"] = df["Sex"].map({"female":0, "male":1})
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex  Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male   22      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female   38      1
# 2                             Heikkinen, Miss. Laina  female   26      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female   35      1
# 4                           Allen, Mr. William Henry    male   35      0
#
#    Parch            Ticket     Fare Cabin Embarked  Gender
# 0      0         A/5 21171   7.2500   NaN        S       1
# 1      0          PC 17599  71.2833   C85        C       0
# 2      0  STON/O2. 3101282   7.9250   NaN        S       0
# 3      0            113803  53.1000  C123        S       0
# ...

# %%
df["Embarked_d"] = df["Embarked"].map({"C":0, "Q":1, "S":2})
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex  Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male   22      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female   38      1
# 2                             Heikkinen, Miss. Laina  female   26      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female   35      1
# 4                           Allen, Mr. William Henry    male   35      0
#
#    Parch            Ticket     Fare Cabin Embarked  Gender  Embarked_d
# 0      0         A/5 21171   7.2500   NaN        S       1           2
# 1      0          PC 17599  71.2833   C85        C       0           0
# 2      0  STON/O2. 3101282   7.9250   NaN        S       0           2
# ...

# %%
df.groupby(['Sex']).sum()
# Out:
#         PassengerId  Survived  Pclass           Age  SibSp  Parch        Fare  \
# Sex
# female       135343       233     678   8860.053235    218    204  13966.6628
# male         262043       109    1379  17601.860588    248    136  14727.2865
#
#         Gender  Embarked_d
# Sex
# female       0         442
# male       577         923

# %%
df.groupby(['Pclass']).sum()
# Out:
#         PassengerId  Survived           Age  SibSp  Parch        Fare  Gender  \
# Pclass
# 1             99705       136   8002.393529     90     77  18177.4125     122
# 2             82056        87   5495.520294     74     70   3801.8417     108
# 3            215625       119  12964.000000    302    193   6714.6951     347
#
#         Embarked_d
# Pclass
# 1              256
# 2              331
# 3              778

# %%
df = df.dropna(axis=0)
df_test = df.loc[:, ("Pclass", "Age", "SibSp", "Parch", "Fare", "Gender", "Embarked_d")]

# %%
df_test['Family'] = df_test['SibSp'] + df_test['Parch']

# %%
df_test['PclassAge'] = df_test['Pclass'] * df_test['Age']

# %%
df_test.head()
# Out:
#     Pclass  Age  SibSp  Parch     Fare  Gender  Embarked_d  Family  PclassAge
# 1        1   38      1      0  71.2833       0           0       1         38
# 3        1   35      1      0  53.1000       0           2       1         35
# 6        1   54      0      0  51.8625       1           2       0         54
# 10       3    4      1      1  16.7000       0           2       2         12
# 11       1   58      0      0  26.5500       0           2       0         58

# %%
df_label = df["Survived"]

# %%
from sklearn.ensemble import RandomForestClassifier
clf = RandomForestClassifier(n_estimators=100)
clf.fit(df_test.values, df_label.values)
# Out:
# RandomForestClassifier(bootstrap=True, compute_importances=None,
#             criterion='gini', max_depth=None, max_features='auto',
#             max_leaf_nodes=None, min_density=None, min_samples_leaf=1,
#             min_samples_split=2, n_estimators=100, n_jobs=1,
#             oob_score=False, random_state=None, verbose=0)

# %%
from sklearn.cross_validation import cross_val_score
scores = cross_val_score(clf, df_test.values, df_label.values) 
print scores
# Out:
# [ 0.76470588  0.75        0.75757576]

# %%
test_data = pd.read_csv('test.csv')

# %%
test_data['Age'].unique()
# Out:
# array([ 34.5 ,  47.  ,  62.  ,  27.  ,  22.  ,  14.  ,  30.  ,  26.  ,
#         18.  ,  21.  ,    nan,  46.  ,  23.  ,  63.  ,  24.  ,  35.  ,
#         45.  ,  55.  ,   9.  ,  48.  ,  50.  ,  22.5 ,  41.  ,  33.  ,
#         18.5 ,  25.  ,  39.  ,  60.  ,  36.  ,  20.  ,  28.  ,  10.  ,
#         17.  ,  32.  ,  13.  ,  31.  ,  29.  ,  28.5 ,  32.5 ,   6.  ,
#         67.  ,  49.  ,   2.  ,  76.  ,  43.  ,  16.  ,   1.  ,  12.  ,
#         42.  ,  53.  ,  26.5 ,  40.  ,  61.  ,  60.5 ,   7.  ,  15.  ,
#         54.  ,  64.  ,  37.  ,  34.  ,  11.5 ,   8.  ,   0.33,  38.  ,
#         57.  ,  40.5 ,   0.92,  19.  ,  36.5 ,   0.75,   0.83,  58.  ,
#          0.17,  59.  ,  14.5 ,  44.  ,   5.  ,  51.  ,   3.  ,  38.5 ])

# %%
test_data['Gender'] = test_data['Sex'].map( {'female': 0, 'male': 1} ).astype(int)
test_data["Embarked_d"] = test_data["Embarked"].map({"C":0, "Q":1, "S":2})
test_data.head()
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked  Gender  Embarked_d
# 0  34.5      0      0   330911   7.8292   NaN        Q       1           1
# 1  47.0      1      0   363272   7.0000   NaN        S       0           2
# 2  62.0      0      0   240276   9.6875   NaN        Q       1           1
# 3  27.0      0      0   315154   8.6625   NaN        S       1           2
# 4  22.0      1      1  3101298  12.2875   NaN        S       0           2

# %%
test_data['AgeFill'] = test_data['Age']
test_data.head()

for i in range(0, 2):
    for j in range(0, 3):
        test_data.loc[ (test_data.Age.isnull()) & (test_data.Gender == i) & (test_data.Pclass == j+1),\
                'AgeFill'] = median_ages[i,j]
        
test_data['AgeIsNull'] = pd.isnull(test_data.Age).astype(int)

# %%
test_data.head()
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked  Gender  Embarked_d  \
# 0  34.5      0      0   330911   7.8292   NaN        Q       1           1
# 1  47.0      1      0   363272   7.0000   NaN        S       0           2
# 2  62.0      0      0   240276   9.6875   NaN        Q       1           1
# 3  27.0      0      0   315154   8.6625   NaN        S       1           2
# 4  22.0      1      1  3101298  12.2875   NaN        S       0           2
#
#    AgeFill  AgeIsNull
# 0     34.5          0
# ...

# %%
test_data = test_data.drop(['Name', 'Sex', 'Ticket', 'Cabin', 'Embarked', 'Age'], axis=1) 
test_data.head()
# Out:
#    PassengerId  Pclass  SibSp  Parch     Fare  Gender  Embarked_d  AgeFill  \
# 0          892       3      0      0   7.8292       1           1     34.5
# 1          893       3      1      0   7.0000       0           2     47.0
# 2          894       2      0      0   9.6875       1           1     62.0
# 3          895       3      0      0   8.6625       1           2     27.0
# 4          896       3      1      1  12.2875       0           2     22.0
#
#    AgeIsNull
# 0          0
# 1          0
# 2          0
# 3          0
# 4          0

# %%
test_data['Age*Class'] = test_data.AgeFill * test_data.Pclass 
test_data['FamilySize'] = test_data['SibSp'] + test_data['Parch']

# %%
test_data.loc[152, :]
# Out:
# PassengerId    1044.0
# Pclass            3.0
# SibSp             0.0
# Parch             0.0
# Fare              NaN
# Gender            1.0
# Embarked_d        2.0
# AgeFill          60.5
# AgeIsNull         0.0
# Age*Class       181.5
# FamilySize        0.0
# Name: 152, dtype: float64

# %%
inds = pd.isnull(test_data).any(1).nonzero()[0]
inds[0:10]
# Out:
# array([152])

# %%
test_data.loc[test_data.Fare.isnull(), 'Fare'] = 0

# %%
test_data.head()
# Out:
#    PassengerId  Pclass  SibSp  Parch     Fare  Gender  Embarked_d  AgeFill  \
# 0          892       3      0      0   7.8292       1           1     34.5
# 1          893       3      1      0   7.0000       0           2     47.0
# 2          894       2      0      0   9.6875       1           1     62.0
# 3          895       3      0      0   8.6625       1           2     27.0
# 4          896       3      1      1  12.2875       0           2     22.0
#
#    AgeIsNull  Age*Class  FamilySize
# 0          0      103.5           0
# 1          0      141.0           1
# 2          0      124.0           0
# 3          0       81.0           0
# 4          0       66.0           2

# %%
output = clf.predict(test_data.values)

# %%
output.shape
# Out:
# (418,)

# %%
result_to_csv = pd.DataFrame(dict(PassengerId = test_data['PassengerId'], Survived=output))
result_to_csv.to_csv('result.csv', header = True, index=False)
